# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image_new = cv2.imread("/content/drive/MyDrive/OPENCV-IMAGES/DEVI.jpg")  
cv2_imshow(image_new)
cv2.waitKey()
cv2.destroyAllWindows()
# image_new.shape
# Out:
# <PIL.Image.Image image mode=RGB size=255x198 at 0x7F92AB4B4B70>

# %%
print("height",int(image_new.shape[0]),"pixell")
# Out:
# height 198 pixell

# %%
print("width",int(image_new.shape[1]),"pixel")
# Out:
# width 255 pixel

# %%
# plt.imshow(image_new, cmap = "gray"), plt.axis("off")
# plt.show()
